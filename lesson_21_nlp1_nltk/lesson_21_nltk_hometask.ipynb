# %% [markdown]
# <font color = green >
#
# # Natural Language Toolkit (NLTK)
#
# </font>

# %% [markdown]
# <font color = green >
#
# ## Home Task
#
# </font>

# %%
# Fix SSL (macOS)
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import nltk
import numpy as np
from nltk.corpus import gutenberg, words
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk import FreqDist
from nltk.stem import WordNetLemmatizer

# Download data
for pkg in ['gutenberg', 'punkt', 'punkt_tab', 'wordnet', 'omw-1.4',
            'words', 'averaged_perceptron_tagger', 'averaged_perceptron_tagger_eng']:
    nltk.download(pkg, quiet=True)

moby_raw = gutenberg.raw('melville-moby_dick.txt')
moby_tokens = nltk.word_tokenize(moby_raw)
correct_spellings = words.words()

print('tokens:', len(moby_tokens))
# Out:
# tokens: 255222

# %% [markdown]
# <font color = green >
#
# ### Example 1
#
# </font>
#
# How many tokens (words and punctuation symbols) are in `moby_raw`?
# <br>*This function should return an integer.*

# %%
def example_one():
    from nltk.tokenize import word_tokenize
    return len(word_tokenize(moby_raw))

# %% [markdown]
# <font color = blue >
#
# ### Check result
#
# </font>

# %%
print ('{:,}'.format(example_one()))
# Out:
# 255,222

# %% [markdown]
# <font color = green >
#
# ### Example 2
#
# </font>
#
# How many unique tokens (unique words and punctuation) does `moby_raw` have?
# <br>*This function should return an integer.*

# %%
def example_two():    
    return len(set(nltk.word_tokenize(moby_raw)))

# %% [markdown]
# <font color = blue >
#
# ### Check result
#
# </font>

# %%
print ('{:,}'.format(example_two()))
# Out:
# 20,639

# %% [markdown]
# <font color = green >
#
# ### Example 3
#
# </font>
#
# After lemmatizing the verbs, how many unique tokens does `moby_raw` have?
# <br>*This function should return an integer.*

# %%
from nltk.stem import WordNetLemmatizer

def example_three():
    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(w,'v') for w in nltk.word_tokenize(moby_raw)]
    return len(set(lemmatized))

# %% [markdown]
# <font color = blue >
#
# ### Check result
#
# </font>

# %%
print ('{:,}'.format(example_three()))
# Out:
# 16,908

# %% [markdown]
# <font color = green >
#
# ### Question 1
#
# </font>
#
#
# What is the lexical diversity of the given text input? (i.e. ratio of unique tokens to the total number of tokens)
# <br>*This function should return a float.*

# %%
def answer_one():
    return len(set(moby_tokens)) / len(moby_tokens)

# %% [markdown]
# <font color = blue >
#
# ### Check result
#
# </font>

# %%
answer_one()
# Out:
# 0.08086685317096488

# %% [markdown]
# <font color = blue >
#
# ### Expected Output
#
# </font>
#
# `0.08139566804842562`

# %% [markdown]
# <font color = green >
#
# ### Question 2
#
# </font>
#
# What percentage of tokens is 'whale'or 'Whale'?
# <br>*This function should return a float.*

# %%
from nltk.tokenize import word_tokenize
def answer_two():
    dist = FreqDist(moby_tokens)
    return (dist['whale'] + dist['Whale']) / len(moby_tokens) * 100

# %% [markdown]
# <font color = blue >
#
# ### Check result
#
# </font>

# %%
answer_two()
# Out:
# 0.41571651346670746

# %% [markdown]
# <font color = blue >
#
# ### Expected Output
#
# </font>
#
# `0.4125668166077752`

# %% [markdown]
# <font color = green >
#
# ### Question 3
#
# </font>
#
# What are the 20 most frequently occurring (unique) tokens in the text? What is their frequency?
# <br>*This function should return a list of 10 tuples where each tuple is of the form `(token, frequency)`. The list should be sorted in descending order of frequency.*

# %%
def answer_three():
    dist = FreqDist(moby_tokens)
    return dist.most_common(20)[:10]

# %% [markdown]
# <font color = blue >
#
# ### Check result
#
# </font>

# %%
answer_three()
# Out:
# [(',', 19204),
#  ('the', 13715),
#  ('.', 7306),
#  ('of', 6513),
#  ('and', 6010),
#  ('a', 4545),
#  ('to', 4515),
#  (';', 4173),
#  ('in', 3908),
#  ('that', 2981)]

# %% [markdown]
# <font color = blue >
#
# ### Expected Output
#
# </font>
#
# `[(',', 19204),
#  ('the', 13715),
#  ('.', 7308),
#  ('of', 6513),
#  ('and', 6010),
#  ('a', 4545),
#  ('to', 4515),
#  (';', 4173),
#  ('in', 3908),
#  ('that', 2978)]`

# %% [markdown]
# <font color = green >
#
# ### Question 4
#
# </font>
#
# What tokens have a length of greater than 5 and frequency of more than 150?
# <br>*This function should return a sorted list of the tokens that match the above constraints. To sort your list, use `sorted()`*

# %%
def answer_four():
    dist = FreqDist(moby_tokens)
    return sorted([w for w in set(moby_tokens) if len(w) > 5 and dist[w] > 150])

# %% [markdown]
# <font color = blue >
#
# ### Check result
#
# </font>

# %%
print (answer_four())
# Out:
# ['Captain', 'Pequod', 'Queequeg', 'Starbuck', 'almost', 'before', 'himself', 'little', 'seemed', 'should', 'though', 'through', 'whales', 'without']

# %% [markdown]
# <font color = blue >
#
# ### Expected Output
#
# </font>
#
# `['Captain', 'Pequod', 'Queequeg', 'Starbuck', 'almost', 'before', 'himself', 'little', 'seemed', 'should', 'though', 'through', 'whales', 'without']`

# %% [markdown]
# <font color = green >
#
# ### Question 5
#
# </font>
#
# Find the longest word in text1 and that word's length.
# <br>
# *This function should return a tuple `(longest_word, length)`.*

# %%
def answer_five():
    w = max(set(moby_tokens), key=len)
    return (w, len(w))

# %% [markdown]
# <font color = blue >
#
# ### Check result
#
# </font>

# %%
answer_five()
# Out:
# ("twelve-o'clock-at-night", 23)

# %% [markdown]
# <font color = blue >
#
# ### Expected Output
#
# </font>
#
# `("twelve-o'clock-at-night", 23)`

# %% [markdown]
# <font color = green >
#
# ### Question 6
#
# </font>
#
# What unique words have a frequency of more than 2000? What is their frequency?
# <br>*This function should return a list of tuples of the form `(frequency, word)` sorted in descending order of frequency.*

# %%
def answer_six():
    dist = FreqDist(moby_tokens)
    result = [(freq, w) for w, freq in dist.items() if w.isalpha() and freq > 2000]
    return sorted(result, reverse=True)

# %% [markdown]
# <font color = blue >
#
# ### Check result
#
# </font>

# %%
print(answer_six())
# Out:
# [(13715, 'the'), (6513, 'of'), (6010, 'and'), (4545, 'a'), (4515, 'to'), (3908, 'in'), (2981, 'that'), (2459, 'his'), (2206, 'it'), (2121, 'I')]

# %% [markdown]
# <font color = blue >
#
# ### Expected Output
#
# </font>
#
# `[(13715, 'the'), (6513, 'of'), (6010, 'and'), (4545, 'a'), (4515, 'to'), (3908, 'in'), (2978, 'that'), (2459, 'his'), (2196, 'it'), (2097, 'I')]`

# %% [markdown]
# <font color = green >
#
# ### Question 7
#
# </font>
#
# What is the average number of tokens per sentence?
# <br>*This function should return a float.*

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
import numpy as np

# %%
def answer_seven():
    sents = sent_tokenize(moby_raw)
    return len(moby_tokens) / len(sents)

# %% [markdown]
# <font color = blue >
#
# ### Check result
#
# </font>

# %%
print(answer_seven())
# Out:
# 25.90560292326431

# %% [markdown]
# <font color = blue >
#
# ### Expected Output
#
# </font>
#
# `25.881952902963864`

# %% [markdown]
# <font color = green >
#
# ### Question 8
#
# </font>
#
# What are the 5 most frequent parts of speech in this text? What is their frequency?
# <br>*This function should return a list of tuples of the form `(part_of_speech, frequency)` sorted in descending order of frequency.*

# %%
def answer_eight():
    tags = nltk.pos_tag(moby_tokens)
    dist = FreqDist(tag for word, tag in tags)
    return dist.most_common(5)

# %% [markdown]
# <font color = blue >
#
# ### Check result
#
# </font>

# %%
print(answer_eight())
# Out:
# [('NN', 32722), ('IN', 28659), ('DT', 25885), (',', 19204), ('JJ', 17598)]

# %% [markdown]
# <font color = blue >
#
# ### Expected Output
#
# </font>
#
# `[('NN', 32730), ('IN', 28657), ('DT', 25867), (',', 19204), ('JJ', 17620)]`

# %% [markdown]
# <font color = green >
#
# ### Question 9
#
# </font>
#
# Create spelling recommender, that take a list of misspelled words and recommends a correctly spelled word for every word in the list.
#
# For every misspelled word, the recommender should find find the word in `correct_spellings` that has the shortest `edit distance` (you may need  to use `nltk.edit_distance(word_1, word_2, transpositions=True)`), and starts with the same letter as the misspelled word, and return that word as a recommendation.
#
# Recommender should provide recommendations for the three words: `['cormulent', 'incendenece', 'validrate']`.
# <br>*This function should return a list of length three:
# `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.*

# %%
from nltk.corpus import words

# %%
def answer_nine(default_words=['cormulent', 'incendenece', 'validrate']):
    result = []
    for word in default_words:
        candidates = [w for w in correct_spellings if w[0] == word[0]]
        best = min(candidates, key=lambda w: nltk.edit_distance(word, w, transpositions=True))
        result.append(best)
    return result

# %% [markdown]
# <font color = blue >
#
# ### Check result
#
# </font>

# %%
answer_nine()
# Out:
# ['corpulent', 'intendence', 'validate']

# %% [markdown]
# <font color = blue >
#
# ### Expected Output
#
# </font>
#
# `['corpulent', 'intendence', 'validate']`
